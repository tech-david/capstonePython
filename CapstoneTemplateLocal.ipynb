# %%
import pandas as pd
import numpy as np

# %%
## Importing from hard coded sources
## TODO make the sources dynamic to user input
fuel_df = pd.read_excel(r"C:\Users\David's PC\OneDrive - Grand Canyon University\Capstone\Data Sources\EIA\Table_9.4_Retail_Motor_Gasoline_and_On-Highway_Diesel_Fuel_Prices.xlsx",
                        header=11)

# %%
## Get access to s3 bucket

import pandas as pd
import boto3

ACCESS=pd.read_csv(r"C:\Users\David's PC\OneDrive - Grand Canyon University\Capstone\AWS\Access\jupyters3access.csv")

AWS_S3_BUCKET="capstoneds2022data"
AWS_ACCESS_KEY_ID=ACCESS['Access key ID'].values[0]
AWS_SECRET_ACCESS_KEY=ACCESS['Secret access key'].values[0]


s3=boto3.resource('s3',
                  aws_access_key_id=AWS_ACCESS_KEY_ID,
                  aws_secret_access_key=AWS_SECRET_ACCESS_KEY)
s3.Bucket(AWS_S3_BUCKET).download_file('Data Sources/EIA/Table_9.10_Natural_Gas_Prices.xlsx', 
                                       r"C:\Users\David's PC\OneDrive - Grand Canyon University\Capstone\Data Sources\tmp\natural_gas")

# %%
natural_gas_df = pd.read_excel(r"C:\Users\David's PC\OneDrive - Grand Canyon University\Capstone\Data Sources\tmp\natural_gas",
                               header=11)
natural_gas_df
# Out:
#     Unnamed: 0 (Dollars per Thousand Cubic Feet)  \
# 0   1976-01-01                              0.54
# 1   1976-02-01                              0.54
# 2   1976-03-01                              0.54
# 3   1976-04-01                              0.55
# 4   1976-05-01                              0.55
# ..         ...                               ...
# 547 2021-08-01                     Not Available
# 548 2021-09-01                     Not Available
# 549 2021-10-01                     Not Available
# 550 2021-11-01                     Not Available
# 551 2021-12-01                     Not Available
#
#     (Dollars per Thousand Cubic Feet).1 (Dollars per Thousand Cubic Feet).2  \
# 0                         Not Available                       Not Available
# 1                         Not Available                       Not Available
# 2                         Not Available                       Not Available
# 3                         Not Available                       Not Available
# 4                         Not Available                       Not Available
# ..                                  ...                                 ...
# 547                                5.67                               20.98
# 548                                6.25                               20.25
# 549                                6.41                                17.5
# 550                                6.03                               13.29
# 551                                5.81                               13.13
#
#          (Percent) (Dollars per Thousand Cubic Feet).3    (Percent).1  \
# 0    Not Available                       Not Available  Not Available
# 1    Not Available                       Not Available  Not Available
# 2    Not Available                       Not Available  Not Available
# 3    Not Available                       Not Available  Not Available
# 4    Not Available                       Not Available  Not Available
# ..             ...                                 ...            ...
# 547           96.5                               10.19           54.7
# 548           96.6                               10.28           56.4
# 549           97.1                               10.45           59.5
# 550             97                               10.11           65.5
# 551           96.7                               10.33           68.3
#
#     (Dollars per Thousand Cubic Feet).4    (Percent).2  \
# 0                         Not Available  Not Available
# 1                         Not Available  Not Available
# 2                         Not Available  Not Available
# 3                         Not Available  Not Available
# 4                         Not Available  Not Available
# ..                                  ...            ...
# 547                                5.01             13
# 548                                5.57           13.7
# 549                                6.84           13.4
# 550                                7.03           13.7
# 551                                6.74             14
#
#     (Dollars per Thousand Cubic Feet).5 (Dollars per Thousand Cubic Feet).6  \
# 0                         Not Available                       Not Available
# 1                         Not Available                       Not Available
# 2                         Not Available                       Not Available
# 3                         Not Available                       Not Available
# 4                         Not Available                       Not Available
# ..                                  ...                                 ...
# 547                       Not Available                                4.45
# 548                       Not Available                                5.09
# 549                       Not Available                                5.75
# 550                       Not Available                                5.89
# 551                       Not Available                                5.15
#
#        (Percent).3
# 0    Not Available
# 1    Not Available
# 2    Not Available
# 3    Not Available
# 4    Not Available
# ..             ...
# 547           86.3
# 548           87.9
# 549           87.8
# 550           87.2
# 551           88.7
#
# [552 rows x 12 columns]

# %%
import pandasgui
from pandasgui import show
import PyQt5.QtWebEngineWidgets

gas_gui=show(natural_gas_df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI

# %%
## Using widgets from ipywidgets
import ipywidgets as widgets
print(dir(widgets))
# Out:
# ['Accordion', 'AppLayout', 'Audio', 'BoundedFloatText', 'BoundedIntText', 'Box', 'Button', 'ButtonStyle', 'CallbackDispatcher', 'Checkbox', 'Color', 'ColorPicker', 'Combobox', 'Controller', 'CoreWidget', 'DOMWidget', 'DatePicker', 'Datetime', 'Dropdown', 'FileUpload', 'FloatLogSlider', 'FloatProgress', 'FloatRangeSlider', 'FloatSlider', 'FloatText', 'GridBox', 'GridspecLayout', 'HBox', 'HTML', 'HTMLMath', 'Image', 'IntProgress', 'IntRangeSlider', 'IntSlider', 'IntText', 'Label', 'Layout', 'NumberFormat', 'Output', 'Password', 'Play', 'RadioButtons', 'Select', 'SelectMultiple', 'SelectionRangeSlider', 'SelectionSlider', 'SliderStyle', 'Style', 'Tab', 'Text', 'Textarea', 'ToggleButton', 'ToggleButtons', 'ToggleButtonsStyle', 'TwoByTwoLayout', 'VBox', 'Valid', 'ValueWidget', 'Video', 'Widget', '__builtins__', '__cached__', '__doc__', '__file__', '__jupyter_widgets_base_version__', '__jupyter_widgets_controls_version__', '__loader__', '__name__', '__package__', '__path__', '__protocol_version__', '__spec__', '__version__', '_handle_ipython', '_version', 'dlink', 'docutils', 'domwidget', 'fixed', 'get_ipython', 'handle_kernel', 'interact', 'interact_manual', 'interaction', 'interactive', 'interactive_output', 'jsdlink', 'jslink', 'link', 'load_ipython_extension', 'os', 'register', 'register_comm_target', 'trait_types', 'util', 'valuewidget', 'version_info', 'widget', 'widget_bool', 'widget_box', 'widget_button', 'widget_color', 'widget_controller', 'widget_core', 'widget_date', 'widget_description', 'widget_float', 'widget_int', 'widget_layout', 'widget_link', 'widget_media', 'widget_output', 'widget_selection', 'widget_selectioncontainer', 'widget_serialization', 'widget_string', 'widget_style', 'widget_templates', 'widget_upload', 'widgets']

# %%
def upload():
    files = []
    upload_widget = widgets.FileUpload(accept='.csv',
                           multiple=True,)
    for x in upload_widget:
        return files.append(x)
    return files
    
upload()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 9>()
#       6         return files.append(x)
#       7     return files
# ----> 9 upload()
#
# Input In [17], in upload()
#       2 files = []
#       3 upload_widget = widgets.FileUpload(accept='.csv',
#       4                        multiple=True,)
# ----> 5 for x in upload_widget:
#       6     return files.append(x)
#       7 return files
#
# TypeError: 'FileUpload' object is not iterable

# %%
upload()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 upload()
#
# TypeError: 'FileUpload' object is not callable
