# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
# Out:
# 2022-07-29 12:31:22.022 INFO    numexpr.utils: Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2022-07-29 12:31:22.023 INFO    numexpr.utils: NumExpr defaulting to 8 threads.

# %%
# ACCESS=pd.read_csv(r"C:\Users\David's PC\OneDrive - Grand Canyon University\Capstone\AWS\Access\jupyters3access.csv")

# AWS_S3_BUCKET="capstoneds2022data"
# AWS_ACCESS_KEY_ID=ACCESS['Access key ID'].values[0]
# AWS_SECRET_ACCESS_KEY=ACCESS['Secret access key'].values[0]


# s3=boto3.resource('s3',
#                   aws_access_key_id=AWS_ACCESS_KEY_ID,
#                   aws_secret_access_key=AWS_SECRET_ACCESS_KEY)
# s3.Bucket(AWS_S3_BUCKET).download_file('Data Sources/EIA/Table_9.10_Natural_Gas_Prices.xlsx', 
#                                        r"C:\Users\David's PC\OneDrive - Grand Canyon University\Capstone\Data Sources\tmp\natural_gas")
# natural_gas_df = pd.read_excel(r"C:\Users\David's PC\OneDrive - Grand Canyon University\Capstone\Data Sources\tmp\natural_gas",
#                                header=11,
#                               index_col=0,
#                               na_values='Not Available',
#                               parse_dates=True)

# st.write(naturag)

# %%
natural_gas = pd.read_csv(r"C:\Users\David's PC\OneDrive - Grand Canyon University\Capstone\Backend\capstonePython\capstonePython\data\Table_9.10_Natural_Gas_Prices.csv")
natural_gas
# Out:
#               Month        Natural Gas Price, Wellhead  \
# 0               NaN  (Dollars per Thousand Cubic Feet)
# 1      1976 January                               0.54
# 2     1976 February                               0.54
# 3        1976 March                               0.54
# 4        1976 April                               0.55
# ..              ...                                ...
# 548     2021 August                      Not Available
# 549  2021 September                      Not Available
# 550    2021 October                      Not Available
# 551   2021 November                      Not Available
# 552   2021 December                      Not Available
#
#            Natural Gas Price, Citygate  \
# 0    (Dollars per Thousand Cubic Feet)
# 1                        Not Available
# 2                        Not Available
# 3                        Not Available
# 4                        Not Available
# ..                                 ...
# ...

# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
@st.cache
def get_gas_data():
    return natural_gas

gas_data = get_gas_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\streamlit\legacy_caching\hashing.py:368, in _CodeHasher.to_bytes(self, obj, context)
#     366 try:
#     367     # Hash the input
# --> 368     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     370     # Hmmm... It's possible that the size calculation is wrong. When we
#     371     # call to_bytes inside _to_bytes things get double-counted.
#
# File C:\ProgramData\Anaconda3\lib\site-packages\streamlit\legacy_caching\hashing.py:634, in _CodeHasher._to_bytes(self, obj, context)
#     633 assert code is not None
# --> 634 if self._file_should_be_hashed(code.co_filename):
#     635     context = _get_context(obj)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\streamlit\legacy_caching\hashing.py:410, in _CodeHasher._file_should_be_hashed(self, filename)
# ...

# %%
st.title("Economic Recession Using Commodities")
st.markdown("A look as to how price increases in consumer commodities impact recession probablity")

st.header("Commodities include:")
st.markdown("> Natural gas, electricity, oil, CPI of common household goods")
# Out:
# 2022-07-29 12:38:25.201
# ...
#   command:
#
#     streamlit run C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)
